# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
project_dir = "/mnt/c/Users/Acer/Graduate/Courses/AI 222/grocery-cv/"
model = YOLO(f"{project_dir}/explore/yolo11m.pt")

# %%
# Predict the image
results = model(f"{project_dir}/explore/test.jpg")
for result in results:
    print(result.names)
    #print(result.names[result.boxes.cls])
    for box in result.boxes:
        cls = result.names[box.cls.item()]
        conf = box.conf.item()
        print(cls, conf)
    result.show()
# Out:
# image 1/1 /mnt/c/Users/Acer/Graduate/Courses/AI 222/grocery-cv/explore/test.jpg: 384x640 1 person, 106.6ms
# Speed: 3.9ms preprocess, 106.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# ...
